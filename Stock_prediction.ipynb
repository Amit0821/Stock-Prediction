# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit0821/Stock-Prediction/blob/main/Stock_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import pandas as pd

# %%
#load dataset from loacl directory
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-df2d970f-e9d0-46c7-a700-b64697f7666f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df2d970f-e9d0-46c7-a700-b64697f7666f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stock_prediction.csv to stock_prediction.csv

# %%
#load dataset
dataset=pd.read_csv('stock_prediction.csv')
dataset
# Out:
#               X           Y
# 0    125.239998  119.980003
# 1    116.379997  114.949997
# 2    115.480003  116.620003
# 3    117.010002  114.970001
# 4    115.510002  115.550003
# ..          ...         ...
# 429  136.000000  135.460007
# 430   29.075001   29.615000
# 431    7.890000    7.960000
# 432   68.510002   69.190002
# 433   15.220000   15.450000
#
# [434 rows x 2 columns]

# %%
#summarize  dataset
print(dataset.shape)
dataset.head()
# Out:
# (434, 2)
#             X           Y
# 0  125.239998  119.980003
# 1  116.379997  114.949997
# 2  115.480003  116.620003
# 3  117.010002  114.970001
# 4  115.510002  115.550003

# %%
dataset.tail()
# Out:
#               X           Y
# 429  136.000000  135.460007
# 430   29.075001   29.615000
# 431    7.890000    7.960000
# 432   68.510002   69.190002
# 433   15.220000   15.450000

# %%
#segregate dataset into x-input and y-output
x=dataset.iloc[:,:-1].values
x
# Out:
# array([[125.239998  ],
#        [116.379997  ],
#        [115.480003  ],
#        [117.010002  ],
#        [115.510002  ],
#        [116.459999  ],
#        [113.510002  ],
#        [113.330002  ],
#        [113.660004  ],
#        [109.059998  ],
#        [109.730003  ],
#        [111.879997  ],
#        [111.32      ],
#        [110.419998  ],
#        [110.769997  ],
#        [110.900002  ],
#        [113.349998  ],
#        [114.        ],
#        [113.25      ],
#        [113.379997  ],
#        [114.080002  ],
#        [115.120003  ],
#        [113.300003  ],
#        [111.169998  ],
#        [106.730003  ],
#        [105.629997  ],
#        [108.559998  ],
#        [109.110001  ],
#        [110.830002  ],
#        [111.120003  ],
#        [111.370003  ],
#        [111.360001  ],
#        [112.370003  ],
#        [110.769997  ],
#        [111.599998  ],
#        [113.339996  ],
#        [113.040001  ],
#        [114.269997  ],
#        [115.349998  ],
#        [116.489998  ],
# ...

# %%
y=dataset.iloc[:,-1].values
y
# Out:
# array([119.980003  , 114.949997  , 116.620003  , 114.970001  ,
#        115.550003  , 112.849998  , 114.379997  , 112.529999  ,
#        110.379997  , 109.300003  , 110.        , 111.949997  ,
#        110.120003  , 111.        , 110.709999  , 112.580002  ,
#        114.470001  , 114.5       , 110.559998  , 114.050003  ,
#        115.709999  , 114.019997  , 111.160004  , 110.650002  ,
#        107.519997  , 107.129997  , 107.839996  , 110.769997  ,
#        111.239998  , 111.599998  , 110.330002  , 113.040001  ,
#        111.889999  , 111.559998  , 112.879997  , 112.75      ,
#        113.32      , 115.510002  , 116.779999  , 117.        ,
#        117.190002  , 116.949997  , 116.709999  , 116.489998  ,
#        116.82      , 120.620003  , 120.629997  , 120.699997  ,
#        120.82      , 124.029999  , 121.269997  , 121.449997  ,
#        121.470001  , 119.379997  , 119.410004  , 118.720001  ,
#        117.980003  , 118.739998  , 118.660004  , 119.93      ,
# ...

# %%
#spliting dataset  for Testing our model
from sklearn.model_selection import  train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
#training dataset using support Vector Regression(SVR)
from sklearn.svm import SVR
model=SVR()
model.fit(x_train,y_train)
# Out:
# SVR()

# %%
#prediction for all test data for validation
#SSres is the sum of squares of the residual errors
#SStot is the total sum of the errors
# R*R=1-SSres/SStot

# %%
ypred=model.predict(x_test)
from sklearn.metrics import r2_score,mean_squared_error
mse=mean_squared_error(y_test,ypred)
rmse=np.sqrt(mse)
print('Root Mean Square Error:',rmse)
r2score=r2_score(y_test,ypred)
print("R2Score",r2score*100)
# Out:
# Root Mean Square Error: 3.9960281982595864
# R2Score 99.19131529695387
